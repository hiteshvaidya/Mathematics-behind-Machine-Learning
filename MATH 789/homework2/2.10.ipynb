# %% [markdown]
# ## Problem 2.10

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
x = np.arange(0.1,3,0.01)

# %%
# %matplotlib notebook
plt.plot(x,np.log(x), label='log(x)')
plt.plot(x, x-1, label='x-1')
plt.plot(1,np.log(1), 'yo', label='log(1)')
plt.plot(1,(1-1), 'r+', label='(1)-1')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
